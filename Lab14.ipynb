# %%
###LAB14 : 22Apr2025
#max no of total for each day for fremont code i.e max count for each day
#replace mean() by max()

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import numpy as np
weekend_array = np.where(data.index.dayofweek <5,'Weekend','Weekend')

print(weekend_array)
#dayofweek----> Monday=0,Sunday=6
by_time=data.groupby([weekend_array,data.index.time]).mean()

print(by_time)

by_time.loc['Weekday'].plot(title='Weekdays',style=[':','--','-'])
by_time.loc['Weekend'].plot(title='Weekends',style=[':','--','-'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 weekend_array = np.where(data.index.dayofweek <5,'Weekend','Weekend')
#       4 print(weekend_array)
#       5 #dayofweek----> Monday=0,Sunday=6
#
# NameError: name 'data' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib
data = pd.read_csv('FremontBridge.csv', parse_dates=[0], index_col=0)
# Assuming 'data' is a pandas DataFrame with a datetime index
weekend_array = np.where(data.index.dayofweek < 5, 'Weekday', 'Weekend')

print(weekend_array)

# Group by both the 'weekend_array' and the time of day, then calculate the mean
by_time = data.groupby([weekend_array, data.index.time]).mean()

print(by_time)

# Plot for Weekdays
by_time.loc['Weekday'].plot(title='Weekdays', style=[':', '--', '-'])

# Plot for Weekends
by_time.loc['Weekend'].plot(title='Weekends', style=[':', '--', '-'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import matplotlib
#       4 data = pd.read_csv('FremontBridge.csv', parse_dates=[0], index_col=0)
#       5 # Assuming 'data' is a pandas DataFrame with a datetime index
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
print(data.dropna().describe())
data.plot()
plt.ylabel('Hourly Bicycle Count')
# Out:
#                Total           East           West
# count  142144.000000  142144.000000  142144.000000
# mean      111.101355      50.571280      60.530075
# std       141.791650      65.360139      88.136627
# min         0.000000       0.000000       0.000000
# 25%        14.000000       6.000000       7.000000
# 50%        60.000000      28.000000      30.000000
# 75%       145.000000      68.000000      74.000000
# max      1097.000000     698.000000     850.000000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 print(data.dropna().describe())
#       2 data.plot()
# ----> 3 plt.ylabel('Hourly Bicycle Count')
#
# NameError: name 'plt' is not defined

# %%
 ###B2 : Births csv
#i)Total no of births by year and month
#ii)Average daily births by day of week and decade

# %%
import pandas as pd
import matplotlib .pyplot as plt
import matplotlib as mpl
import numpy as np

births = pd.read_csv('births.csv')
print(births.head())
print(births.dtypes)
print(births.describe())
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548
# year        int64
# month       int64
# day       float64
# gender     object
# births      int64
# dtype: object
#                year         month           day         births
# count  15547.000000  15547.000000  15067.000000   15547.000000
# mean    1979.037435      6.515919     17.769894    9762.293561
# std        6.728340      3.449632     15.284034   28552.465810
# min     1969.000000      1.000000      1.000000       1.000000
# 25%     1974.000000      4.000000      8.000000    4358.000000
# 50%     1979.000000      7.000000     16.000000    4814.000000
# 75%     1984.000000     10.000000     24.000000    5289.500000
# max     2008.000000     12.000000     99.000000  199622.000000

# %%
births.pivot_table('births',index='year',columns='gender',aggfunc='sum').plot()
plt.ylabel('total births per year')
# Out:
# Text(0, 0.5, 'total births per year')

# %%
temp=births.pivot_table('births',index='year',columns='gender',aggfunc='sum')
pd.pivot_table(births,index='year',columns='gender',aggfunc='sum',values='births').plot()
print(temp)
plt.ylabel('total births per year')
# Out:
# gender        F        M
# year
# 1969    1753634  1846572
# 1970    1819164  1918636
# 1971    1736774  1826774
# 1972    1592347  1673888
# 1973    1533102  1613023
# 1974    1543005  1627626
# 1975    1535546  1618010
# 1976    1547613  1628863
# 1977    1623363  1708796
# 1978    1626324  1711976
# 1979    1705837  1793958
# 1980    1762459  1855522
# 1981    1772037  1863478
# 1982    1797239  1888218
# 1983    1775299  1867522
# 1984    1791802  1881766
# 1985    1834774  1930290
# 1986    1833708  1926987
# 1987    1860111  1953105
# 1988    1909210  2004583
# 1989    1973712  2071981
# 1990    2030966  2131951
# 1991    2011601  2103741
# 1992    1985118  2084310
# 1993    1953456  2051067
# 1994    1932234  2024691
# 1995    1904871  1998141
# 1996    1902664  1992210
# 1997    1896928  1987401
# 1998    1927106  2018086
# 1999    1934510  2028955
# 2000    1984255  2079568
# 2001    1970770  2060761
# 2002    1966519  2060857
# 2003    1999387  2096705
# ...

# %%
temp=births.pivot_table('births',index='year',aggfunc='sum')
pd.pivot_table(births,index='year',aggfunc='sum',values='births').plot()
print(temp)
plt.ylabel('total births per year')
# Out:
#        births
# year
# 1969  3600206
# 1970  3737800
# 1971  3563548
# 1972  3266235
# 1973  3146125
# 1974  3170631
# 1975  3153556
# 1976  3176476
# 1977  3332159
# 1978  3338300
# 1979  3499795
# 1980  3617981
# 1981  3635515
# 1982  3685457
# 1983  3642821
# 1984  3673568
# 1985  3765064
# 1986  3760695
# 1987  3813216
# 1988  3913793
# 1989  4045693
# 1990  4162917
# 1991  4115342
# 1992  4069428
# 1993  4004523
# 1994  3956925
# 1995  3903012
# 1996  3894874
# 1997  3884329
# 1998  3945192
# 1999  3963465
# 2000  4063823
# 2001  4031531
# 2002  4027376
# 2003  4096092
# 2004  4118907
# 2005  4145619
# 2006  4273225
# 2007  4324008
# 2008  4255156
# Text(0, 0.5, 'total births per year')

# %%
births['decade']=10 * (births['year'] //10)
#print(births['decade'])
#print(births)
#births.pivot_table('births',index='decade',columns='gender'.aggfunc='sum').plot()
print(type(births))
births['day']=births['day'].astype(int)
births.index=pd.to_datetime(10000 * births.year + 100 * births.month + births.day ,format='%Y%m%d')
births['dayofweek']=births.index.dayofweek
#print(births)
print(births.head())
births.pivot_table('births',index='dayofweek',columns='decade',aggfunc='mean')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[40], line 6
#       2 #print(births['decade'])
#       3 #print(births)
#       4 #births.pivot_table('births',index='decade',columns='gender'.aggfunc='sum').plot()
#       5 print(type(births))
# ----> 6 births['day']=births['day'].astype(int)
#       7 births.index=pd.to_datetime(10000 * births.year + 100 * births.month + births.day ,format='%Y%m%d')
#       8 births['dayofweek']=births.index.dayofweek
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# ...
